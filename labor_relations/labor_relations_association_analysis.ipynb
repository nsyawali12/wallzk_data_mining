# %% [markdown]
# # TUGAS DATA MINING

# %%
#import sys
#!conda install --yes --prefix {sys.prefix} plotly

# %%
#pip install apyori

# %% [markdown]
# # Import Library

# %%
import numpy as np # linear algebra
import pandas as pd # data processing
import plotly.express as px
import apyori
from apyori import apriori

# %% [markdown]
# # Import Dataset

# %%
data = pd.read_csv('labor.csv')

# %%
data.head()
# Out:
#   duration wage-increase-first-year wage-increase-second-year  \
# 0        1                        5                         ?
# 1        2                      4.5                       5.8
# 2        ?                        ?                         ?
# 3        3                      3.7                         4
# 4        3                      4.5                       4.5
#
#   wage-increase-third-year cost-of-living-adjustment working-hours  \
# 0                        ?                         ?            40
# 1                        ?                         ?            35
# 2                        ?                         ?            38
# 3                        5                        tc             ?
# 4                        5                         ?            40
#
#       pension standby-pay shift-differential education-allowance  \
# 0           ?           ?                  2                   ?
# 1    ret_allw           ?                  ?                 yes
# 2  empl_contr           ?                  5                   ?
# 3           ?           ?                  ?                 yes
# 4           ?           ?                  ?                   ?
#
#   statutory-holidays       vacation longterm-disability-assistance  \
# 0                 11        average                              ?
# 1                 11  below_average                              ?
# 2                 11       generous                            yes
# 3                  ?              ?                              ?
# 4                 12        average                              ?
#
#   contribution-to-dental-plan bereavement-assistance  \
# 0                           ?                    yes
# 1                        full                      ?
# 2                        half                    yes
# 3                           ?                    yes
# 4                        half                    yes
#
#   contribution-to-health-plan class
# 0                           ?  good
# 1                        full  good
# 2                        half  good
# 3                           ?  good
# 4                        half  good

# %%
data.shape
# Out:
# (57, 17)

# %%
data.dtypes
# Out:
# duration                          object
# wage-increase-first-year          object
# wage-increase-second-year         object
# wage-increase-third-year          object
# cost-of-living-adjustment         object
# working-hours                     object
# pension                           object
# standby-pay                       object
# shift-differential                object
# education-allowance               object
# statutory-holidays                object
# vacation                          object
# longterm-disability-assistance    object
# contribution-to-dental-plan       object
# bereavement-assistance            object
# contribution-to-health-plan       object
# class                             object
# dtype: object

# %% [markdown]
# Ganti value "?" dengan NaN atau Null

# %%
data.replace('?', np.nan, inplace= True)
data
# Out:
#    duration wage-increase-first-year wage-increase-second-year  \
# 0         1                        5                       NaN
# 1         2                      4.5                       5.8
# 2       NaN                      NaN                       NaN
# 3         3                      3.7                         4
# 4         3                      4.5                       4.5
# 5         2                        2                       2.5
# 6         3                        4                         5
# 7         3                      6.9                       4.8
# 8         2                        3                         7
# 9         1                      5.7                       NaN
# 10        3                      3.5                         4
# 11        2                      6.4                       6.4
# 12        2                      3.5                         4
# 13        3                      3.5                         4
# 14        1                        3                       NaN
# 15        2                      4.5                         4
# 16        1                      2.8                       NaN
# 17        1                      2.1                       NaN
# 18        1                        2                       NaN
# 19        2                        4                         5
# 20        2                      4.3                       4.4
# 21        2                      2.5                         3
# 22        3                      3.5                         4
# 23        2                      4.5                         4
# 24        1                        6                       NaN
# 25        3                        2                         2
# 26        2                      4.5                       4.5
# 27        2                        3                         3
# 28        2                        5                         4
# 29        3                        2                       2.5
# 30        3                      4.5                       4.5
# 31        3                        3                         2
# 32        2                      2.5                       2.5
# 33        2                        4                         5
# 34        3                        2                       2.5
# 35        2                        2                         2
# 36        1                        2                       NaN
# 37        1                      2.8                       NaN
# 38        3                        2                       2.5
# 39        2                      4.5                         4
# 40        1                        4                       NaN
# 41        2                        2                         3
# 42        2                      2.5                       2.5
# 43        2                      2.5                         3
# 44        2                        4                         4
# 45        2                      4.5                         4
# 46        2                      4.5                         4
# 47        2                      4.6                       4.6
# 48        2                        5                       4.5
# 49        2                      5.7                       4.5
# 50        2                        7                       5.3
# 51        3                        2                         3
# 52        3                      3.5                         4
# 53        3                        4                       3.5
# 54        3                        5                       4.4
# 55        3                        5                         5
# 56        3                        6                         6
#
#    wage-increase-third-year cost-of-living-adjustment working-hours  \
# 0                       NaN                       NaN            40
# 1                       NaN                       NaN            35
# 2                       NaN                       NaN            38
# 3                         5                        tc           NaN
# 4                         5                       NaN            40
# 5                       NaN                       NaN            35
# 6                         5                        tc           NaN
# 7                       2.3                       NaN            40
# 8                       NaN                       NaN            38
# 9                       NaN                      none            40
# 10                      4.6                      none            36
# 11                      NaN                       NaN            38
# 12                      NaN                      none            40
# 13                      5.1                       tcf            37
# 14                      NaN                      none            36
# 15                      NaN                      none            37
# 16                      NaN                       NaN            35
# 17                      NaN                        tc            40
# 18                      NaN                      none            38
# 19                      NaN                       tcf            35
# 20                      NaN                       NaN            38
# 21                      NaN                       NaN            40
# 22                      4.6                       tcf            27
# 23                      NaN                       NaN            40
# 24                      NaN                       NaN            38
# 25                        2                      none            40
# 26                      NaN                       tcf           NaN
# 27                      NaN                      none            33
# 28                      NaN                      none            37
# 29                      NaN                       NaN            35
# 30                        5                      none            40
# 31                      2.5                        tc            40
# 32                      NaN                       NaN            38
# 33                      NaN                      none            40
# 34                      2.1                        tc            40
# 35                      NaN                      none            40
# 36                      NaN                        tc            40
# 37                      NaN                      none            38
# 38                        2                       NaN            37
# 39                      NaN                      none            40
# 40                      NaN                      none           NaN
# 41                      NaN                      none            38
# 42                      NaN                        tc            39
# 43                      NaN                       tcf            40
# 44                      NaN                      none            40
# 45                      NaN                       NaN            40
# 46                      NaN                      none            40
# 47                      NaN                       tcf            38
# 48                      NaN                      none            38
# 49                      NaN                      none            40
# 50                      NaN                       NaN           NaN
# 51                      NaN                       tcf           NaN
# 52                      4.5                       tcf            35
# 53                      NaN                      none            40
# 54                      NaN                      none            38
# 55                        5                       NaN            40
# 56                        4                       NaN            35
#
#        pension standby-pay shift-differential education-allowance  \
# 0          NaN         NaN                  2                 NaN
# 1     ret_allw         NaN                NaN                 yes
# 2   empl_contr         NaN                  5                 NaN
# 3          NaN         NaN                NaN                 yes
# 4          NaN         NaN                NaN                 NaN
# 5          NaN         NaN                  6                 yes
# 6   empl_contr         NaN                NaN                 NaN
# 7          NaN         NaN                  3                 NaN
# 8          NaN          12                 25                 yes
# 9   empl_contr         NaN                  4                 NaN
# 10         NaN         NaN                  3                 NaN
# 11         NaN         NaN                  4                 NaN
# 12         NaN         NaN                  2                  no
# 13         NaN         NaN                  4                 NaN
# 14         NaN         NaN                 10                  no
# 15  empl_contr         NaN                NaN                 NaN
# 16         NaN         NaN                  2                 NaN
# 17    ret_allw           2                  3                  no
# 18        none         NaN                NaN                 yes
# 19         NaN          13                  5                 NaN
# 20         NaN         NaN                  4                 NaN
# 21        none         NaN                NaN                 NaN
# 22         NaN         NaN                NaN                 NaN
# 23         NaN         NaN                  4                 NaN
# 24         NaN           8                  3                 NaN
# 25        none         NaN                NaN                 NaN
# 26         NaN         NaN                NaN                 yes
# 27         NaN         NaN                NaN                 yes
# 28         NaN         NaN                  5                  no
# 29        none         NaN                NaN                 NaN
# 30         NaN         NaN                NaN                  no
# 31        none         NaN                  5                  no
# 32  empl_contr         NaN                NaN                 NaN
# 33        none         NaN                  3                  no
# 34        none           2                  1                  no
# 35        none         NaN                NaN                  no
# 36    ret_allw           4                  0                  no
# 37  empl_contr           2                  3                  no
# 38  empl_contr         NaN                NaN                 NaN
# 39         NaN         NaN                  4                 NaN
# 40        none         NaN                NaN                 yes
# 41  empl_contr         NaN                NaN                 yes
# 42  empl_contr         NaN                NaN                 NaN
# 43        none         NaN                NaN                 NaN
# 44        none         NaN                  3                 NaN
# 45         NaN         NaN                  2                  no
# 46         NaN         NaN                  5                 NaN
# 47         NaN         NaN                NaN                 NaN
# 48         NaN          14                  5                 NaN
# 49    ret_allw         NaN                NaN                 NaN
# 50         NaN         NaN                NaN                 NaN
# 51  empl_contr         NaN                NaN                 yes
# 52         NaN         NaN                NaN                 NaN
# 53  empl_contr         NaN                  6                 NaN
# 54  empl_contr          10                  6                 NaN
# 55         NaN         NaN                NaN                 NaN
# 56         NaN         NaN                 14                 NaN
#
#    statutory-holidays       vacation longterm-disability-assistance  \
# 0                  11        average                            NaN
# 1                  11  below_average                            NaN
# 2                  11       generous                            yes
# 3                 NaN            NaN                            NaN
# 4                  12        average                            NaN
# 5                  12        average                            NaN
# 6                  12       generous                            yes
# 7                  12  below_average                            NaN
# 8                  11  below_average                            yes
# 9                  11       generous                            yes
# 10                 13       generous                            NaN
# 11                 15            NaN                            NaN
# 12                 10  below_average                             no
# 13                 13       generous                            NaN
# 14                 11       generous                            NaN
# 15                 11        average                            NaN
# 16                 12  below_average                            NaN
# 17                  9  below_average                            yes
# 18                 11        average                             no
# 19                 15       generous                            NaN
# 20                 12       generous                            NaN
# 21                 11  below_average                            NaN
# 22                NaN            NaN                            NaN
# 23                 10       generous                            NaN
# 24                  9       generous                            NaN
# 25                 10  below_average                            NaN
# 26                 10  below_average                            yes
# 27                 12       generous                            NaN
# 28                 11  below_average                            yes
# 29                 10        average                            NaN
# 30                 11        average                            NaN
# 31                 10  below_average                            yes
# 32                 10        average                            NaN
# 33                 10  below_average                             no
# 34                 10  below_average                             no
# 35                 11        average                            yes
# 36                 11       generous                             no
# 37                  9  below_average                            yes
# 38                 10        average                            NaN
# 39                 12        average                            yes
# 40                 11        average                             no
# 41                 12       generous                            yes
# 42                 12        average                            NaN
# 43                 11  below_average                            NaN
# 44                 10  below_average                             no
# 45                 10  below_average                             no
# 46                 11        average                            NaN
# 47                NaN            NaN                            yes
# 48                 11  below_average                            yes
# 49                 11        average                            yes
# 50                 11            NaN                            yes
# 51                NaN            NaN                            yes
# 52                 13       generous                            NaN
# 53                 11        average                            yes
# 54                 11       generous                            yes
# 55                 12        average                            NaN
# 56                  9       generous                            yes
#
#    contribution-to-dental-plan bereavement-assistance  \
# 0                          NaN                    yes
# 1                         full                    NaN
# 2                         half                    yes
# 3                          NaN                    yes
# 4                         half                    yes
# 5                          NaN                    NaN
# 6                         none                    yes
# 7                          NaN                    NaN
# 8                         half                    yes
# 9                         full                    NaN
# 10                         NaN                    yes
# 11                        full                    NaN
# 12                        half                    NaN
# 13                        full                    yes
# 14                         NaN                    NaN
# 15                        full                    yes
# 16                         NaN                    NaN
# 17                        half                    NaN
# 18                        none                     no
# 19                         NaN                    NaN
# 20                        full                    NaN
# 21                         NaN                    NaN
# 22                         NaN                    NaN
# 23                        half                    NaN
# 24                         NaN                    NaN
# 25                        half                    yes
# 26                        none                    NaN
# 27                         NaN                    yes
# 28                        full                    yes
# 29                         NaN                    yes
# 30                        half                    NaN
# 31                        half                    yes
# 32                         NaN                    NaN
# 33                        none                    NaN
# 34                        half                    yes
# 35                        none                    yes
# 36                        none                     no
# 37                        half                    NaN
# 38                         NaN                    yes
# 39                        full                    yes
# 40                        none                     no
# 41                        none                    yes
# 42                         NaN                    yes
# 43                         NaN                    yes
# 44                        none                    NaN
# 45                        half                    NaN
# 46                        full                    yes
# 47                        half                    NaN
# 48                         NaN                    NaN
# 49                        full                    yes
# 50                        full                    NaN
# 51                        half                    yes
# 52                         NaN                    yes
# 53                        full                    NaN
# 54                         NaN                    NaN
# 55                        half                    yes
# 56                        full                    yes
#
#    contribution-to-health-plan class
# 0                          NaN  good
# 1                         full  good
# 2                         half  good
# 3                          NaN  good
# 4                         half  good
# 5                          NaN  good
# 6                         half  good
# 7                          NaN  good
# 8                          NaN  good
# 9                          NaN  good
# 10                        full  good
# 11                         NaN  good
# 12                        half   bad
# 13                        full  good
# 14                         NaN  good
# 15                         NaN  good
# 16                         NaN  good
# 17                        none   bad
# 18                        none   bad
# 19                         NaN  good
# 20                        full  good
# 21                         NaN   bad
# 22                         NaN  good
# 23                        full  good
# 24                         NaN  good
# 25                        full   bad
# 26                        half  good
# 27                        full  good
# 28                        full  good
# 29                        full   bad
# 30                         NaN  good
# 31                        full   bad
# 32                         NaN   bad
# 33                        none   bad
# 34                        full   bad
# 35                        full   bad
# 36                        none   bad
# 37                        none   bad
# 38                        none   bad
# 39                        half  good
# 40                        none   bad
# 41                        full   bad
# 42                         NaN   bad
# 43                         NaN   bad
# 44                        none   bad
# 45                        half   bad
# 46                        full  good
# 47                        half  good
# 48                        full  good
# 49                        full  good
# 50                         NaN  good
# 51                         NaN  good
# 52                        full  good
# 53                        full  good
# 54                        full  good
# 55                        half  good
# 56                        full  good

# %%
data.rename(columns = {'class':'kelas'}, inplace = True)

# %%
data.rename(columns = {'wage-increase-first-year':'WIFirstYear'}, inplace = True)

# %%
data.rename(columns = {'wage-increase-second-year':'WISecondYear'}, inplace = True)

# %%
data.rename(columns = {'wage-increase-third-year':'WIThirdYear'}, inplace = True)

# %%
data.drop('kelas', axis=1, inplace=True)

# %% [markdown]
# Lihat Jumlah Data yang Nan dalam Setiap Variabel

# %%
data.isnull().sum()
# Out:
# duration                           1
# WIFirstYear                        1
# WISecondYear                      11
# WIThirdYear                       42
# cost-of-living-adjustment         20
# working-hours                      6
# pension                           30
# standby-pay                       48
# shift-differential                26
# education-allowance               35
# statutory-holidays                 4
# vacation                           6
# longterm-disability-assistance    29
# contribution-to-dental-plan       20
# bereavement-assistance            27
# contribution-to-health-plan       20
# dtype: int64

# %% [markdown]
# Isi Value NaN untuk setiap Variabel dengan Top Values pada Setiap Variabel

# %%
data['duration']=data['duration'].replace(['1','2','3'], ['duration1','duration2','duration3'])

# %%
data['duration'].describe()
# Out:
# count            56
# unique            3
# top       duration2
# freq             27
# Name: duration, dtype: object

# %%
data['duration'] = data['duration'].fillna('duration2')
data.head(5)
# Out:
#     duration WIFirstYear WISecondYear WIThirdYear cost-of-living-adjustment  \
# 0  duration1           5          NaN         NaN                       NaN
# 1  duration2         4.5          5.8         NaN                       NaN
# 2          2         NaN          NaN         NaN                       NaN
# 3  duration3         3.7            4           5                        tc
# 4  duration3         4.5          4.5           5                       NaN
#
#   working-hours     pension standby-pay shift-differential  \
# 0            40         NaN         NaN                  2
# 1            35    ret_allw         NaN                NaN
# 2            38  empl_contr         NaN                  5
# 3           NaN         NaN         NaN                NaN
# 4            40         NaN         NaN                NaN
#
#   education-allowance statutory-holidays       vacation  \
# 0                 NaN                 11        average
# 1                 yes                 11  below_average
# 2                 NaN                 11       generous
# 3                 yes                NaN            NaN
# 4                 NaN                 12        average
#
#   longterm-disability-assistance contribution-to-dental-plan  \
# 0                            NaN                         NaN
# 1                            NaN                        full
# 2                            yes                        half
# 3                            NaN                         NaN
# 4                            NaN                        half
#
#   bereavement-assistance contribution-to-health-plan
# 0                    yes                         NaN
# 1                    NaN                        full
# 2                    yes                        half
# 3                    yes                         NaN
# 4                    yes                        half

# %%
data['WIFirstYear'].describe()
# Out:
# count     56
# unique    17
# top        2
# freq      10
# Name: WIFirstYear, dtype: object

# %%
data['WIFirstYear'] = data['WIFirstYear'].fillna('2')
data.head(5)
# Out:
#     duration WIFirstYear WISecondYear WIThirdYear cost-of-living-adjustment  \
# 0  duration1           5          NaN         NaN                       NaN
# 1  duration2         4.5          5.8         NaN                       NaN
# 2          2           2          NaN         NaN                       NaN
# 3  duration3         3.7            4           5                        tc
# 4  duration3         4.5          4.5           5                       NaN
#
#   working-hours     pension standby-pay shift-differential  \
# 0            40         NaN         NaN                  2
# 1            35    ret_allw         NaN                NaN
# 2            38  empl_contr         NaN                  5
# 3           NaN         NaN         NaN                NaN
# 4            40         NaN         NaN                NaN
#
#   education-allowance statutory-holidays       vacation  \
# 0                 NaN                 11        average
# 1                 yes                 11  below_average
# 2                 NaN                 11       generous
# 3                 yes                NaN            NaN
# 4                 NaN                 12        average
#
#   longterm-disability-assistance contribution-to-dental-plan  \
# 0                            NaN                         NaN
# 1                            NaN                        full
# 2                            yes                        half
# 3                            NaN                         NaN
# 4                            NaN                        half
#
#   bereavement-assistance contribution-to-health-plan
# 0                    yes                         NaN
# 1                    NaN                        full
# 2                    yes                        half
# 3                    yes                         NaN
# 4                    yes                        half

# %%
a = data['WIFirstYear'].unique()
a.sort()
a
# Out:
# array(['2', '2.1', '2.5', '2.8', '3', '3.5', '3.7', '4', '4.3', '4.5',
#        '4.6', '5', '5.7', '6', '6.4', '6.9', '7'], dtype=object)

# %%
data['WIFirstYear']=data['WIFirstYear'].replace(['2', '2.1', '2.5', '2.8', '3', '3.5', '3.7', '4', '4.3', '4.5',
       '4.6', '5', '5.7', '6', '6.4', '6.9', '7'], ['wageFirst2', 'wageFirst2.1', 'wageFirst2.5', 'wageFirst2.8', 'wageFirst3', 'wageFirst3.5', 'wageFirst3.7', 'wageFirst4', 'wageFirst4.3', 'wageFirst4.5',
       'wageFirst4.6', 'wageFirst5', 'wageFirst5.7', 'wageFirst6', 'wageFirst6.4', 'wageFirst6.9', 'wageFirst7'])

# %%
data['WISecondYear'].describe()
# Out:
# count     46
# unique    15
# top        4
# freq      13
# Name: WISecondYear, dtype: object

# %%
data['WISecondYear'] = data['WISecondYear'].fillna('4')
data.head(5)
# Out:
#     duration   WIFirstYear WISecondYear WIThirdYear cost-of-living-adjustment  \
# 0  duration1    wageFirst5            4         NaN                       NaN
# 1  duration2  wageFirst4.5          5.8         NaN                       NaN
# 2          2    wageFirst2            4         NaN                       NaN
# 3  duration3  wageFirst3.7            4           5                        tc
# 4  duration3  wageFirst4.5          4.5           5                       NaN
#
#   working-hours     pension standby-pay shift-differential  \
# 0            40         NaN         NaN                  2
# 1            35    ret_allw         NaN                NaN
# 2            38  empl_contr         NaN                  5
# 3           NaN         NaN         NaN                NaN
# 4            40         NaN         NaN                NaN
#
#   education-allowance statutory-holidays       vacation  \
# 0                 NaN                 11        average
# 1                 yes                 11  below_average
# 2                 NaN                 11       generous
# 3                 yes                NaN            NaN
# 4                 NaN                 12        average
#
#   longterm-disability-assistance contribution-to-dental-plan  \
# 0                            NaN                         NaN
# 1                            NaN                        full
# 2                            yes                        half
# 3                            NaN                         NaN
# 4                            NaN                        half
#
#   bereavement-assistance contribution-to-health-plan
# 0                    yes                         NaN
# 1                    NaN                        full
# 2                    yes                        half
# 3                    yes                         NaN
# 4                    yes                        half

# %%
a = data['WISecondYear'].unique()
a.sort()
a
# Out:
# array(['2', '2.5', '3', '3.5', '4', '4.4', '4.5', '4.6', '4.8', '5',
#        '5.3', '5.8', '6', '6.4', '7'], dtype=object)

# %%
data['WISecondYear']=data['WISecondYear'].replace(['2', '2.5', '3', '3.5', '4', '4.4', '4.5', '4.6', '4.8', '5',
       '5.3', '5.8', '6', '6.4', '7'], ['wageSecond2', 'wageSecond2.5', 'wageSecond3', 'wageSecond3.5', 'wageSecond4', 'wageSecond4.4', 'wageSecond4.5', 'wageSecond4.6', 'wageSecond4.8', 'wageSecond5',
       'wageSecond5.3', 'wageSecond5.8', 'wageSecond6', 'wageSecond6.4', 'wageSecond7'])

# %%
data['WIThirdYear'].describe()
# Out:
# count     15
# unique     9
# top        5
# freq       5
# Name: WIThirdYear, dtype: object

# %%
data['WIThirdYear'] = data['WIThirdYear'].fillna('5')
data.head(5)
# Out:
#     duration   WIFirstYear   WISecondYear WIThirdYear  \
# 0  duration1    wageFirst5    wageSecond4           5
# 1  duration2  wageFirst4.5  wageSecond5.8           5
# 2          2    wageFirst2    wageSecond4           5
# 3  duration3  wageFirst3.7    wageSecond4           5
# 4  duration3  wageFirst4.5  wageSecond4.5           5
#
#   cost-of-living-adjustment working-hours     pension standby-pay  \
# 0                       NaN            40         NaN         NaN
# 1                       NaN            35    ret_allw         NaN
# 2                       NaN            38  empl_contr         NaN
# 3                        tc           NaN         NaN         NaN
# 4                       NaN            40         NaN         NaN
#
#   shift-differential education-allowance statutory-holidays       vacation  \
# 0                  2                 NaN                 11        average
# 1                NaN                 yes                 11  below_average
# 2                  5                 NaN                 11       generous
# 3                NaN                 yes                NaN            NaN
# 4                NaN                 NaN                 12        average
#
#   longterm-disability-assistance contribution-to-dental-plan  \
# 0                            NaN                         NaN
# 1                            NaN                        full
# 2                            yes                        half
# 3                            NaN                         NaN
# 4                            NaN                        half
#
#   bereavement-assistance contribution-to-health-plan
# 0                    yes                         NaN
# 1                    NaN                        full
# 2                    yes                        half
# 3                    yes                         NaN
# 4                    yes                        half

# %%
a = data['WIThirdYear'].unique()
a.sort()
a
# Out:
# array(['2', '2.1', '2.3', '2.5', '4', '4.5', '4.6', '5', '5.1'],
#       dtype=object)

# %%
data['WIThirdYear']=data['WIThirdYear'].replace(['2', '2.1', '2.3', '2.5', '4', '4.5', '4.6', '5', '5.1'], ['wageThrid2', 'wageThrid2.1', 'wageThrid2.3', 'wageThrid2.5', 'wageThrid4', 'wageThrid4.5', 'wageThrid4.6', 'wageThrid5', 'wageThrid5.1'])

# %%
data['cost-of-living-adjustment'].describe()
# Out:
# count       37
# unique       3
# top       none
# freq        22
# Name: cost-of-living-adjustment, dtype: object

# %%
data['cost-of-living-adjustment'] = data['cost-of-living-adjustment'].fillna('none')
data.head(5)
# Out:
#     duration   WIFirstYear   WISecondYear WIThirdYear  \
# 0  duration1    wageFirst5    wageSecond4  wageThrid5
# 1  duration2  wageFirst4.5  wageSecond5.8  wageThrid5
# 2          2    wageFirst2    wageSecond4  wageThrid5
# 3  duration3  wageFirst3.7    wageSecond4  wageThrid5
# 4  duration3  wageFirst4.5  wageSecond4.5  wageThrid5
#
#   cost-of-living-adjustment working-hours     pension standby-pay  \
# 0                      none            40         NaN         NaN
# 1                      none            35    ret_allw         NaN
# 2                      none            38  empl_contr         NaN
# 3                        tc           NaN         NaN         NaN
# 4                      none            40         NaN         NaN
#
#   shift-differential education-allowance statutory-holidays       vacation  \
# 0                  2                 NaN                 11        average
# 1                NaN                 yes                 11  below_average
# 2                  5                 NaN                 11       generous
# 3                NaN                 yes                NaN            NaN
# 4                NaN                 NaN                 12        average
#
#   longterm-disability-assistance contribution-to-dental-plan  \
# 0                            NaN                         NaN
# 1                            NaN                        full
# 2                            yes                        half
# 3                            NaN                         NaN
# 4                            NaN                        half
#
#   bereavement-assistance contribution-to-health-plan
# 0                    yes                         NaN
# 1                    NaN                        full
# 2                    yes                        half
# 3                    yes                         NaN
# 4                    yes                        half

# %%
a = data['cost-of-living-adjustment'].unique()
a.sort()
a
# Out:
# array(['none', 'tc', 'tcf'], dtype=object)

# %%
data['cost-of-living-adjustment']=data['cost-of-living-adjustment'].replace(['none', 'tc', 'tcf'], ['colanone', 'colatc', 'colatcf'])

# %%
data['working-hours'].describe()
# Out:
# count     51
# unique     8
# top       40
# freq      23
# Name: working-hours, dtype: object

# %%
data['working-hours'] = data['working-hours'].fillna('40')
data.head(5)
# Out:
#     duration   WIFirstYear   WISecondYear WIThirdYear  \
# 0  duration1    wageFirst5    wageSecond4  wageThrid5
# 1  duration2  wageFirst4.5  wageSecond5.8  wageThrid5
# 2          2    wageFirst2    wageSecond4  wageThrid5
# 3  duration3  wageFirst3.7    wageSecond4  wageThrid5
# 4  duration3  wageFirst4.5  wageSecond4.5  wageThrid5
#
#   cost-of-living-adjustment working-hours     pension standby-pay  \
# 0                  colanone            40         NaN         NaN
# 1                  colanone            35    ret_allw         NaN
# 2                  colanone            38  empl_contr         NaN
# 3                    colatc            40         NaN         NaN
# 4                  colanone            40         NaN         NaN
#
#   shift-differential education-allowance statutory-holidays       vacation  \
# 0                  2                 NaN                 11        average
# 1                NaN                 yes                 11  below_average
# 2                  5                 NaN                 11       generous
# 3                NaN                 yes                NaN            NaN
# 4                NaN                 NaN                 12        average
#
#   longterm-disability-assistance contribution-to-dental-plan  \
# 0                            NaN                         NaN
# 1                            NaN                        full
# 2                            yes                        half
# 3                            NaN                         NaN
# 4                            NaN                        half
#
#   bereavement-assistance contribution-to-health-plan
# 0                    yes                         NaN
# 1                    NaN                        full
# 2                    yes                        half
# 3                    yes                         NaN
# 4                    yes                        half

# %%
a = data['working-hours'].unique()
a.sort()
a
# Out:
# array(['27', '33', '35', '36', '37', '38', '39', '40'], dtype=object)

# %%
data['working-hours']=data['working-hours'].replace(['27', '33', '35', '36', '37', '38', '39', '40'], ['workinghours27', 'workinghours33', 'workinghours35', 'workinghours36', 'workinghours37', 'workinghours38', 'workinghours39', 'workinghours40'])

# %%
data['pension'].describe()
# Out:
# count             27
# unique             3
# top       empl_contr
# freq              12
# Name: pension, dtype: object

# %%
data['pension'] = data['pension'].fillna('empl_contr')
data.head(5)
# Out:
#     duration   WIFirstYear   WISecondYear WIThirdYear  \
# 0  duration1    wageFirst5    wageSecond4  wageThrid5
# 1  duration2  wageFirst4.5  wageSecond5.8  wageThrid5
# 2          2    wageFirst2    wageSecond4  wageThrid5
# 3  duration3  wageFirst3.7    wageSecond4  wageThrid5
# 4  duration3  wageFirst4.5  wageSecond4.5  wageThrid5
#
#   cost-of-living-adjustment   working-hours     pension standby-pay  \
# 0                  colanone  workinghours40  empl_contr         NaN
# 1                  colanone  workinghours35    ret_allw         NaN
# 2                  colanone  workinghours38  empl_contr         NaN
# 3                    colatc  workinghours40  empl_contr         NaN
# 4                  colanone  workinghours40  empl_contr         NaN
#
#   shift-differential education-allowance statutory-holidays       vacation  \
# 0                  2                 NaN                 11        average
# 1                NaN                 yes                 11  below_average
# 2                  5                 NaN                 11       generous
# 3                NaN                 yes                NaN            NaN
# 4                NaN                 NaN                 12        average
#
#   longterm-disability-assistance contribution-to-dental-plan  \
# 0                            NaN                         NaN
# 1                            NaN                        full
# 2                            yes                        half
# 3                            NaN                         NaN
# 4                            NaN                        half
#
#   bereavement-assistance contribution-to-health-plan
# 0                    yes                         NaN
# 1                    NaN                        full
# 2                    yes                        half
# 3                    yes                         NaN
# 4                    yes                        half

# %%
a = data['pension'].unique()
a.sort()
a
# Out:
# array(['empl_contr', 'none', 'ret_allw'], dtype=object)

# %%
data['pension']=data['pension'].replace(['none'], ['pensioun_none'])

# %%
data['standby-pay'].describe()
# Out:
# count     9
# unique    7
# top       2
# freq      3
# Name: standby-pay, dtype: object

# %%
data['standby-pay'] = data['standby-pay'].fillna('2')
data.head(5)
# Out:
#     duration   WIFirstYear   WISecondYear WIThirdYear  \
# 0  duration1    wageFirst5    wageSecond4  wageThrid5
# 1  duration2  wageFirst4.5  wageSecond5.8  wageThrid5
# 2          2    wageFirst2    wageSecond4  wageThrid5
# 3  duration3  wageFirst3.7    wageSecond4  wageThrid5
# 4  duration3  wageFirst4.5  wageSecond4.5  wageThrid5
#
#   cost-of-living-adjustment   working-hours     pension standby-pay  \
# 0                  colanone  workinghours40  empl_contr           2
# 1                  colanone  workinghours35    ret_allw           2
# 2                  colanone  workinghours38  empl_contr           2
# 3                    colatc  workinghours40  empl_contr           2
# 4                  colanone  workinghours40  empl_contr           2
#
#   shift-differential education-allowance statutory-holidays       vacation  \
# 0                  2                 NaN                 11        average
# 1                NaN                 yes                 11  below_average
# 2                  5                 NaN                 11       generous
# 3                NaN                 yes                NaN            NaN
# 4                NaN                 NaN                 12        average
#
#   longterm-disability-assistance contribution-to-dental-plan  \
# 0                            NaN                         NaN
# 1                            NaN                        full
# 2                            yes                        half
# 3                            NaN                         NaN
# 4                            NaN                        half
#
#   bereavement-assistance contribution-to-health-plan
# 0                    yes                         NaN
# 1                    NaN                        full
# 2                    yes                        half
# 3                    yes                         NaN
# 4                    yes                        half

# %%
a = data['standby-pay'].unique()
a.sort()
a
# Out:
# array(['10', '12', '13', '14', '2', '4', '8'], dtype=object)

# %%
data['standby-pay']=data['standby-pay'].replace(['10', '12', '13', '14', '2', '4', '8'], ['standByPay10', 'standByPay12', 'standByPay13', 'standByPay14', 'standByPay2', 'standByPay4', 'standByPay8'])

# %%
data['shift-differential'].describe()
# Out:
# count     31
# unique    10
# top        3
# freq       7
# Name: shift-differential, dtype: object

# %%
data['shift-differential'] = data['shift-differential'].fillna('3')
data.head(5)
# Out:
#     duration   WIFirstYear   WISecondYear WIThirdYear  \
# 0  duration1    wageFirst5    wageSecond4  wageThrid5
# 1  duration2  wageFirst4.5  wageSecond5.8  wageThrid5
# 2          2    wageFirst2    wageSecond4  wageThrid5
# 3  duration3  wageFirst3.7    wageSecond4  wageThrid5
# 4  duration3  wageFirst4.5  wageSecond4.5  wageThrid5
#
#   cost-of-living-adjustment   working-hours     pension  standby-pay  \
# 0                  colanone  workinghours40  empl_contr  standByPay2
# 1                  colanone  workinghours35    ret_allw  standByPay2
# 2                  colanone  workinghours38  empl_contr  standByPay2
# 3                    colatc  workinghours40  empl_contr  standByPay2
# 4                  colanone  workinghours40  empl_contr  standByPay2
#
#   shift-differential education-allowance statutory-holidays       vacation  \
# 0                  2                 NaN                 11        average
# 1                  3                 yes                 11  below_average
# 2                  5                 NaN                 11       generous
# 3                  3                 yes                NaN            NaN
# 4                  3                 NaN                 12        average
#
#   longterm-disability-assistance contribution-to-dental-plan  \
# 0                            NaN                         NaN
# 1                            NaN                        full
# 2                            yes                        half
# 3                            NaN                         NaN
# 4                            NaN                        half
#
#   bereavement-assistance contribution-to-health-plan
# 0                    yes                         NaN
# 1                    NaN                        full
# 2                    yes                        half
# 3                    yes                         NaN
# 4                    yes                        half

# %%
a = data['shift-differential'].unique()
a.sort()
a
# Out:
# array(['0', '1', '10', '14', '2', '25', '3', '4', '5', '6'], dtype=object)

# %%
data['shift-differential']=data['shift-differential'].replace(['0', '1', '10', '14', '2', '25', '3', '4', '5', '6'], ['Sd_0', 'Sd_1', 'Sd_10', 'Sd_14', 'Sd_2', 'Sd_25', 'Sd_3', 'Sd_4', 'Sd_5', 'Sd_6'])

# %%
data['education-allowance'].describe()
# Out:
# count     22
# unique     2
# top       no
# freq      12
# Name: education-allowance, dtype: object

# %%
data['education-allowance'] = data['education-allowance'].fillna('no')
data.head(5)
# Out:
#     duration   WIFirstYear   WISecondYear WIThirdYear  \
# 0  duration1    wageFirst5    wageSecond4  wageThrid5
# 1  duration2  wageFirst4.5  wageSecond5.8  wageThrid5
# 2          2    wageFirst2    wageSecond4  wageThrid5
# 3  duration3  wageFirst3.7    wageSecond4  wageThrid5
# 4  duration3  wageFirst4.5  wageSecond4.5  wageThrid5
#
#   cost-of-living-adjustment   working-hours     pension  standby-pay  \
# 0                  colanone  workinghours40  empl_contr  standByPay2
# 1                  colanone  workinghours35    ret_allw  standByPay2
# 2                  colanone  workinghours38  empl_contr  standByPay2
# 3                    colatc  workinghours40  empl_contr  standByPay2
# 4                  colanone  workinghours40  empl_contr  standByPay2
#
#   shift-differential education-allowance statutory-holidays       vacation  \
# 0               Sd_2                  no                 11        average
# 1               Sd_3                 yes                 11  below_average
# 2               Sd_5                  no                 11       generous
# 3               Sd_3                 yes                NaN            NaN
# 4               Sd_3                  no                 12        average
#
#   longterm-disability-assistance contribution-to-dental-plan  \
# 0                            NaN                         NaN
# 1                            NaN                        full
# 2                            yes                        half
# 3                            NaN                         NaN
# 4                            NaN                        half
#
#   bereavement-assistance contribution-to-health-plan
# 0                    yes                         NaN
# 1                    NaN                        full
# 2                    yes                        half
# 3                    yes                         NaN
# 4                    yes                        half

# %%
a = data['education-allowance'].unique()
a.sort()
a
# Out:
# array(['no', 'yes'], dtype=object)

# %%
data['statutory-holidays'].describe()
# Out:
# count     53
# unique     6
# top       11
# freq      21
# Name: statutory-holidays, dtype: object

# %%
data['statutory-holidays'] = data['statutory-holidays'].fillna('11')
data.head(5)
# Out:
#     duration   WIFirstYear   WISecondYear WIThirdYear  \
# 0  duration1    wageFirst5    wageSecond4  wageThrid5
# 1  duration2  wageFirst4.5  wageSecond5.8  wageThrid5
# 2          2    wageFirst2    wageSecond4  wageThrid5
# 3  duration3  wageFirst3.7    wageSecond4  wageThrid5
# 4  duration3  wageFirst4.5  wageSecond4.5  wageThrid5
#
#   cost-of-living-adjustment   working-hours     pension  standby-pay  \
# 0                  colanone  workinghours40  empl_contr  standByPay2
# 1                  colanone  workinghours35    ret_allw  standByPay2
# 2                  colanone  workinghours38  empl_contr  standByPay2
# 3                    colatc  workinghours40  empl_contr  standByPay2
# 4                  colanone  workinghours40  empl_contr  standByPay2
#
#   shift-differential education-allowance statutory-holidays       vacation  \
# 0               Sd_2                  no                 11        average
# 1               Sd_3                 yes                 11  below_average
# 2               Sd_5                  no                 11       generous
# 3               Sd_3                 yes                 11            NaN
# 4               Sd_3                  no                 12        average
#
#   longterm-disability-assistance contribution-to-dental-plan  \
# 0                            NaN                         NaN
# 1                            NaN                        full
# 2                            yes                        half
# 3                            NaN                         NaN
# 4                            NaN                        half
#
#   bereavement-assistance contribution-to-health-plan
# 0                    yes                         NaN
# 1                    NaN                        full
# 2                    yes                        half
# 3                    yes                         NaN
# 4                    yes                        half

# %%
a = data['statutory-holidays'].unique()
a.sort()
a
# Out:
# array(['10', '11', '12', '13', '15', '9'], dtype=object)

# %%
data['statutory-holidays']=data['statutory-holidays'].replace(['10', '11', '12', '13', '15', '9'], ['sHoliday_10', 'sHoliday_11', 'sHoliday_12', 'sHoliday_13', 'sHoliday_15', 'sHoliday_9'])

# %%
data['vacation'].describe()
# Out:
# count                51
# unique                3
# top       below_average
# freq                 18
# Name: vacation, dtype: object

# %%
data['vacation'] = data['vacation'].fillna('below_average')
data.head(5)
# Out:
#     duration   WIFirstYear   WISecondYear WIThirdYear  \
# 0  duration1    wageFirst5    wageSecond4  wageThrid5
# 1  duration2  wageFirst4.5  wageSecond5.8  wageThrid5
# 2          2    wageFirst2    wageSecond4  wageThrid5
# 3  duration3  wageFirst3.7    wageSecond4  wageThrid5
# 4  duration3  wageFirst4.5  wageSecond4.5  wageThrid5
#
#   cost-of-living-adjustment   working-hours     pension  standby-pay  \
# 0                  colanone  workinghours40  empl_contr  standByPay2
# 1                  colanone  workinghours35    ret_allw  standByPay2
# 2                  colanone  workinghours38  empl_contr  standByPay2
# 3                    colatc  workinghours40  empl_contr  standByPay2
# 4                  colanone  workinghours40  empl_contr  standByPay2
#
#   shift-differential education-allowance statutory-holidays       vacation  \
# 0               Sd_2                  no        sHoliday_11        average
# 1               Sd_3                 yes        sHoliday_11  below_average
# 2               Sd_5                  no        sHoliday_11       generous
# 3               Sd_3                 yes        sHoliday_11  below_average
# 4               Sd_3                  no        sHoliday_12        average
#
#   longterm-disability-assistance contribution-to-dental-plan  \
# 0                            NaN                         NaN
# 1                            NaN                        full
# 2                            yes                        half
# 3                            NaN                         NaN
# 4                            NaN                        half
#
#   bereavement-assistance contribution-to-health-plan
# 0                    yes                         NaN
# 1                    NaN                        full
# 2                    yes                        half
# 3                    yes                         NaN
# 4                    yes                        half

# %%
a = data['vacation'].unique()
a.sort()
a
# Out:
# array(['average', 'below_average', 'generous'], dtype=object)

# %%
data['longterm-disability-assistance'].describe()
# Out:
# count      28
# unique      2
# top       yes
# freq       20
# Name: longterm-disability-assistance, dtype: object

# %%
data['longterm-disability-assistance'] = data['longterm-disability-assistance'].fillna('yes')
data.head(5)
# Out:
#     duration   WIFirstYear   WISecondYear WIThirdYear  \
# 0  duration1    wageFirst5    wageSecond4  wageThrid5
# 1  duration2  wageFirst4.5  wageSecond5.8  wageThrid5
# 2          2    wageFirst2    wageSecond4  wageThrid5
# 3  duration3  wageFirst3.7    wageSecond4  wageThrid5
# 4  duration3  wageFirst4.5  wageSecond4.5  wageThrid5
#
#   cost-of-living-adjustment   working-hours     pension  standby-pay  \
# 0                  colanone  workinghours40  empl_contr  standByPay2
# 1                  colanone  workinghours35    ret_allw  standByPay2
# 2                  colanone  workinghours38  empl_contr  standByPay2
# 3                    colatc  workinghours40  empl_contr  standByPay2
# 4                  colanone  workinghours40  empl_contr  standByPay2
#
#   shift-differential education-allowance statutory-holidays       vacation  \
# 0               Sd_2                  no        sHoliday_11        average
# 1               Sd_3                 yes        sHoliday_11  below_average
# 2               Sd_5                  no        sHoliday_11       generous
# 3               Sd_3                 yes        sHoliday_11  below_average
# 4               Sd_3                  no        sHoliday_12        average
#
#   longterm-disability-assistance contribution-to-dental-plan  \
# 0                            yes                         NaN
# 1                            yes                        full
# 2                            yes                        half
# 3                            yes                         NaN
# 4                            yes                        half
#
#   bereavement-assistance contribution-to-health-plan
# 0                    yes                         NaN
# 1                    NaN                        full
# 2                    yes                        half
# 3                    yes                         NaN
# 4                    yes                        half

# %%
a = data['longterm-disability-assistance'].unique()
a.sort()
a
# Out:
# array(['no', 'yes'], dtype=object)

# %%
data['contribution-to-dental-plan'].describe()
# Out:
# count       37
# unique       3
# top       half
# freq        15
# Name: contribution-to-dental-plan, dtype: object

# %%
data['contribution-to-dental-plan'] = data['contribution-to-dental-plan'].fillna('half')
data.head(5)
# Out:
#     duration   WIFirstYear   WISecondYear WIThirdYear  \
# 0  duration1    wageFirst5    wageSecond4  wageThrid5
# 1  duration2  wageFirst4.5  wageSecond5.8  wageThrid5
# 2          2    wageFirst2    wageSecond4  wageThrid5
# 3  duration3  wageFirst3.7    wageSecond4  wageThrid5
# 4  duration3  wageFirst4.5  wageSecond4.5  wageThrid5
#
#   cost-of-living-adjustment   working-hours     pension  standby-pay  \
# 0                  colanone  workinghours40  empl_contr  standByPay2
# 1                  colanone  workinghours35    ret_allw  standByPay2
# 2                  colanone  workinghours38  empl_contr  standByPay2
# 3                    colatc  workinghours40  empl_contr  standByPay2
# 4                  colanone  workinghours40  empl_contr  standByPay2
#
#   shift-differential education-allowance statutory-holidays       vacation  \
# 0               Sd_2                  no        sHoliday_11        average
# 1               Sd_3                 yes        sHoliday_11  below_average
# 2               Sd_5                  no        sHoliday_11       generous
# 3               Sd_3                 yes        sHoliday_11  below_average
# 4               Sd_3                  no        sHoliday_12        average
#
#   longterm-disability-assistance contribution-to-dental-plan  \
# 0                            yes                        half
# 1                            yes                        full
# 2                            yes                        half
# 3                            yes                        half
# 4                            yes                        half
#
#   bereavement-assistance contribution-to-health-plan
# 0                    yes                         NaN
# 1                    NaN                        full
# 2                    yes                        half
# 3                    yes                         NaN
# 4                    yes                        half

# %%
a = data['contribution-to-dental-plan'].unique()
a.sort()
a
# Out:
# array(['full', 'half', 'none'], dtype=object)

# %%
data['contribution-to-dental-plan']=data['contribution-to-dental-plan'].replace(['none'], ['dentalplan_none'])

# %%
data['bereavement-assistance'].describe()
# Out:
# count      30
# unique      2
# top       yes
# freq       27
# Name: bereavement-assistance, dtype: object

# %%
data['bereavement-assistance'] = data['bereavement-assistance'].fillna('yes')
data.head(5)
# Out:
#     duration   WIFirstYear   WISecondYear WIThirdYear  \
# 0  duration1    wageFirst5    wageSecond4  wageThrid5
# 1  duration2  wageFirst4.5  wageSecond5.8  wageThrid5
# 2          2    wageFirst2    wageSecond4  wageThrid5
# 3  duration3  wageFirst3.7    wageSecond4  wageThrid5
# 4  duration3  wageFirst4.5  wageSecond4.5  wageThrid5
#
#   cost-of-living-adjustment   working-hours     pension  standby-pay  \
# 0                  colanone  workinghours40  empl_contr  standByPay2
# 1                  colanone  workinghours35    ret_allw  standByPay2
# 2                  colanone  workinghours38  empl_contr  standByPay2
# 3                    colatc  workinghours40  empl_contr  standByPay2
# 4                  colanone  workinghours40  empl_contr  standByPay2
#
#   shift-differential education-allowance statutory-holidays       vacation  \
# 0               Sd_2                  no        sHoliday_11        average
# 1               Sd_3                 yes        sHoliday_11  below_average
# 2               Sd_5                  no        sHoliday_11       generous
# 3               Sd_3                 yes        sHoliday_11  below_average
# 4               Sd_3                  no        sHoliday_12        average
#
#   longterm-disability-assistance contribution-to-dental-plan  \
# 0                            yes                        half
# 1                            yes                        full
# 2                            yes                        half
# 3                            yes                        half
# 4                            yes                        half
#
#   bereavement-assistance contribution-to-health-plan
# 0                    yes                         NaN
# 1                    yes                        full
# 2                    yes                        half
# 3                    yes                         NaN
# 4                    yes                        half

# %%
a = data['bereavement-assistance'].unique()
a.sort()
a
# Out:
# array(['no', 'yes'], dtype=object)

# %%
data['contribution-to-health-plan'].describe()
# Out:
# count       37
# unique       3
# top       full
# freq        20
# Name: contribution-to-health-plan, dtype: object

# %%
data['contribution-to-health-plan'] = data['contribution-to-health-plan'].fillna('full')
data.head(5)
# Out:
#     duration   WIFirstYear   WISecondYear WIThirdYear  \
# 0  duration1    wageFirst5    wageSecond4  wageThrid5
# 1  duration2  wageFirst4.5  wageSecond5.8  wageThrid5
# 2          2    wageFirst2    wageSecond4  wageThrid5
# 3  duration3  wageFirst3.7    wageSecond4  wageThrid5
# 4  duration3  wageFirst4.5  wageSecond4.5  wageThrid5
#
#   cost-of-living-adjustment   working-hours     pension  standby-pay  \
# 0                  colanone  workinghours40  empl_contr  standByPay2
# 1                  colanone  workinghours35    ret_allw  standByPay2
# 2                  colanone  workinghours38  empl_contr  standByPay2
# 3                    colatc  workinghours40  empl_contr  standByPay2
# 4                  colanone  workinghours40  empl_contr  standByPay2
#
#   shift-differential education-allowance statutory-holidays       vacation  \
# 0               Sd_2                  no        sHoliday_11        average
# 1               Sd_3                 yes        sHoliday_11  below_average
# 2               Sd_5                  no        sHoliday_11       generous
# 3               Sd_3                 yes        sHoliday_11  below_average
# 4               Sd_3                  no        sHoliday_12        average
#
#   longterm-disability-assistance contribution-to-dental-plan  \
# 0                            yes                        half
# 1                            yes                        full
# 2                            yes                        half
# 3                            yes                        half
# 4                            yes                        half
#
#   bereavement-assistance contribution-to-health-plan
# 0                    yes                        full
# 1                    yes                        full
# 2                    yes                        half
# 3                    yes                        full
# 4                    yes                        half

# %%
a = data['contribution-to-health-plan'].unique()
a.sort()
a
# Out:
# array(['full', 'half', 'none'], dtype=object)

# %%
data['contribution-to-health-plan']=data['contribution-to-health-plan'].replace(['none'], ['healtsplan_none'])

# %%
total = data.isnull().sum().sort_values(ascending=False)
percent_1 = data.isnull().sum()/data.isnull().count()*100
percent_2 = (round(percent_1, 1)).sort_values(ascending=False)
missing_data = pd.concat([total, percent_2], axis=1, keys=['Total', '%'])
missing_data.head()
# Out:
#                                 Total    %
# contribution-to-health-plan         0  0.0
# bereavement-assistance              0  0.0
# contribution-to-dental-plan         0  0.0
# longterm-disability-assistance      0  0.0
# vacation                            0  0.0

# %%
data
# Out:
#      duration   WIFirstYear   WISecondYear   WIThirdYear  \
# 0   duration1    wageFirst5    wageSecond4    wageThrid5
# 1   duration2  wageFirst4.5  wageSecond5.8    wageThrid5
# 2           2    wageFirst2    wageSecond4    wageThrid5
# 3   duration3  wageFirst3.7    wageSecond4    wageThrid5
# 4   duration3  wageFirst4.5  wageSecond4.5    wageThrid5
# 5   duration2    wageFirst2  wageSecond2.5    wageThrid5
# 6   duration3    wageFirst4    wageSecond5    wageThrid5
# 7   duration3  wageFirst6.9  wageSecond4.8  wageThrid2.3
# 8   duration2    wageFirst3    wageSecond7    wageThrid5
# 9   duration1  wageFirst5.7    wageSecond4    wageThrid5
# 10  duration3  wageFirst3.5    wageSecond4  wageThrid4.6
# 11  duration2  wageFirst6.4  wageSecond6.4    wageThrid5
# 12  duration2  wageFirst3.5    wageSecond4    wageThrid5
# 13  duration3  wageFirst3.5    wageSecond4  wageThrid5.1
# 14  duration1    wageFirst3    wageSecond4    wageThrid5
# 15  duration2  wageFirst4.5    wageSecond4    wageThrid5
# 16  duration1  wageFirst2.8    wageSecond4    wageThrid5
# 17  duration1  wageFirst2.1    wageSecond4    wageThrid5
# 18  duration1    wageFirst2    wageSecond4    wageThrid5
# 19  duration2    wageFirst4    wageSecond5    wageThrid5
# 20  duration2  wageFirst4.3  wageSecond4.4    wageThrid5
# 21  duration2  wageFirst2.5    wageSecond3    wageThrid5
# 22  duration3  wageFirst3.5    wageSecond4  wageThrid4.6
# 23  duration2  wageFirst4.5    wageSecond4    wageThrid5
# 24  duration1    wageFirst6    wageSecond4    wageThrid5
# 25  duration3    wageFirst2    wageSecond2    wageThrid2
# 26  duration2  wageFirst4.5  wageSecond4.5    wageThrid5
# 27  duration2    wageFirst3    wageSecond3    wageThrid5
# 28  duration2    wageFirst5    wageSecond4    wageThrid5
# 29  duration3    wageFirst2  wageSecond2.5    wageThrid5
# 30  duration3  wageFirst4.5  wageSecond4.5    wageThrid5
# 31  duration3    wageFirst3    wageSecond2  wageThrid2.5
# 32  duration2  wageFirst2.5  wageSecond2.5    wageThrid5
# 33  duration2    wageFirst4    wageSecond5    wageThrid5
# 34  duration3    wageFirst2  wageSecond2.5  wageThrid2.1
# 35  duration2    wageFirst2    wageSecond2    wageThrid5
# 36  duration1    wageFirst2    wageSecond4    wageThrid5
# 37  duration1  wageFirst2.8    wageSecond4    wageThrid5
# 38  duration3    wageFirst2  wageSecond2.5    wageThrid2
# 39  duration2  wageFirst4.5    wageSecond4    wageThrid5
# 40  duration1    wageFirst4    wageSecond4    wageThrid5
# 41  duration2    wageFirst2    wageSecond3    wageThrid5
# 42  duration2  wageFirst2.5  wageSecond2.5    wageThrid5
# 43  duration2  wageFirst2.5    wageSecond3    wageThrid5
# 44  duration2    wageFirst4    wageSecond4    wageThrid5
# 45  duration2  wageFirst4.5    wageSecond4    wageThrid5
# 46  duration2  wageFirst4.5    wageSecond4    wageThrid5
# 47  duration2  wageFirst4.6  wageSecond4.6    wageThrid5
# 48  duration2    wageFirst5  wageSecond4.5    wageThrid5
# 49  duration2  wageFirst5.7  wageSecond4.5    wageThrid5
# 50  duration2    wageFirst7  wageSecond5.3    wageThrid5
# 51  duration3    wageFirst2    wageSecond3    wageThrid5
# 52  duration3  wageFirst3.5    wageSecond4  wageThrid4.5
# 53  duration3    wageFirst4  wageSecond3.5    wageThrid5
# 54  duration3    wageFirst5  wageSecond4.4    wageThrid5
# 55  duration3    wageFirst5    wageSecond5    wageThrid5
# 56  duration3    wageFirst6    wageSecond6    wageThrid4
#
#    cost-of-living-adjustment   working-hours        pension   standby-pay  \
# 0                   colanone  workinghours40     empl_contr   standByPay2
# 1                   colanone  workinghours35       ret_allw   standByPay2
# 2                   colanone  workinghours38     empl_contr   standByPay2
# 3                     colatc  workinghours40     empl_contr   standByPay2
# 4                   colanone  workinghours40     empl_contr   standByPay2
# 5                   colanone  workinghours35     empl_contr   standByPay2
# 6                     colatc  workinghours40     empl_contr   standByPay2
# 7                   colanone  workinghours40     empl_contr   standByPay2
# 8                   colanone  workinghours38     empl_contr  standByPay12
# 9                   colanone  workinghours40     empl_contr   standByPay2
# 10                  colanone  workinghours36     empl_contr   standByPay2
# 11                  colanone  workinghours38     empl_contr   standByPay2
# 12                  colanone  workinghours40     empl_contr   standByPay2
# 13                   colatcf  workinghours37     empl_contr   standByPay2
# 14                  colanone  workinghours36     empl_contr   standByPay2
# 15                  colanone  workinghours37     empl_contr   standByPay2
# 16                  colanone  workinghours35     empl_contr   standByPay2
# 17                    colatc  workinghours40       ret_allw   standByPay2
# 18                  colanone  workinghours38  pensioun_none   standByPay2
# 19                   colatcf  workinghours35     empl_contr  standByPay13
# 20                  colanone  workinghours38     empl_contr   standByPay2
# 21                  colanone  workinghours40  pensioun_none   standByPay2
# 22                   colatcf  workinghours27     empl_contr   standByPay2
# 23                  colanone  workinghours40     empl_contr   standByPay2
# 24                  colanone  workinghours38     empl_contr   standByPay8
# 25                  colanone  workinghours40  pensioun_none   standByPay2
# 26                   colatcf  workinghours40     empl_contr   standByPay2
# 27                  colanone  workinghours33     empl_contr   standByPay2
# 28                  colanone  workinghours37     empl_contr   standByPay2
# 29                  colanone  workinghours35  pensioun_none   standByPay2
# 30                  colanone  workinghours40     empl_contr   standByPay2
# 31                    colatc  workinghours40  pensioun_none   standByPay2
# 32                  colanone  workinghours38     empl_contr   standByPay2
# 33                  colanone  workinghours40  pensioun_none   standByPay2
# 34                    colatc  workinghours40  pensioun_none   standByPay2
# 35                  colanone  workinghours40  pensioun_none   standByPay2
# 36                    colatc  workinghours40       ret_allw   standByPay4
# 37                  colanone  workinghours38     empl_contr   standByPay2
# 38                  colanone  workinghours37     empl_contr   standByPay2
# 39                  colanone  workinghours40     empl_contr   standByPay2
# 40                  colanone  workinghours40  pensioun_none   standByPay2
# 41                  colanone  workinghours38     empl_contr   standByPay2
# 42                    colatc  workinghours39     empl_contr   standByPay2
# 43                   colatcf  workinghours40  pensioun_none   standByPay2
# 44                  colanone  workinghours40  pensioun_none   standByPay2
# 45                  colanone  workinghours40     empl_contr   standByPay2
# 46                  colanone  workinghours40     empl_contr   standByPay2
# 47                   colatcf  workinghours38     empl_contr   standByPay2
# 48                  colanone  workinghours38     empl_contr  standByPay14
# 49                  colanone  workinghours40       ret_allw   standByPay2
# 50                  colanone  workinghours40     empl_contr   standByPay2
# 51                   colatcf  workinghours40     empl_contr   standByPay2
# 52                   colatcf  workinghours35     empl_contr   standByPay2
# 53                  colanone  workinghours40     empl_contr   standByPay2
# 54                  colanone  workinghours38     empl_contr  standByPay10
# 55                  colanone  workinghours40     empl_contr   standByPay2
# 56                  colanone  workinghours35     empl_contr   standByPay2
#
#    shift-differential education-allowance statutory-holidays       vacation  \
# 0                Sd_2                  no        sHoliday_11        average
# 1                Sd_3                 yes        sHoliday_11  below_average
# 2                Sd_5                  no        sHoliday_11       generous
# 3                Sd_3                 yes        sHoliday_11  below_average
# 4                Sd_3                  no        sHoliday_12        average
# 5                Sd_6                 yes        sHoliday_12        average
# 6                Sd_3                  no        sHoliday_12       generous
# 7                Sd_3                  no        sHoliday_12  below_average
# 8               Sd_25                 yes        sHoliday_11  below_average
# 9                Sd_4                  no        sHoliday_11       generous
# 10               Sd_3                  no        sHoliday_13       generous
# 11               Sd_4                  no        sHoliday_15  below_average
# 12               Sd_2                  no        sHoliday_10  below_average
# 13               Sd_4                  no        sHoliday_13       generous
# 14              Sd_10                  no        sHoliday_11       generous
# 15               Sd_3                  no        sHoliday_11        average
# 16               Sd_2                  no        sHoliday_12  below_average
# 17               Sd_3                  no         sHoliday_9  below_average
# 18               Sd_3                 yes        sHoliday_11        average
# 19               Sd_5                  no        sHoliday_15       generous
# 20               Sd_4                  no        sHoliday_12       generous
# 21               Sd_3                  no        sHoliday_11  below_average
# 22               Sd_3                  no        sHoliday_11  below_average
# 23               Sd_4                  no        sHoliday_10       generous
# 24               Sd_3                  no         sHoliday_9       generous
# 25               Sd_3                  no        sHoliday_10  below_average
# 26               Sd_3                 yes        sHoliday_10  below_average
# 27               Sd_3                 yes        sHoliday_12       generous
# 28               Sd_5                  no        sHoliday_11  below_average
# 29               Sd_3                  no        sHoliday_10        average
# 30               Sd_3                  no        sHoliday_11        average
# 31               Sd_5                  no        sHoliday_10  below_average
# 32               Sd_3                  no        sHoliday_10        average
# 33               Sd_3                  no        sHoliday_10  below_average
# 34               Sd_1                  no        sHoliday_10  below_average
# 35               Sd_3                  no        sHoliday_11        average
# 36               Sd_0                  no        sHoliday_11       generous
# 37               Sd_3                  no         sHoliday_9  below_average
# 38               Sd_3                  no        sHoliday_10        average
# 39               Sd_4                  no        sHoliday_12        average
# 40               Sd_3                 yes        sHoliday_11        average
# 41               Sd_3                 yes        sHoliday_12       generous
# 42               Sd_3                  no        sHoliday_12        average
# 43               Sd_3                  no        sHoliday_11  below_average
# 44               Sd_3                  no        sHoliday_10  below_average
# 45               Sd_2                  no        sHoliday_10  below_average
# 46               Sd_5                  no        sHoliday_11        average
# 47               Sd_3                  no        sHoliday_11  below_average
# 48               Sd_5                  no        sHoliday_11  below_average
# 49               Sd_3                  no        sHoliday_11        average
# 50               Sd_3                  no        sHoliday_11  below_average
# 51               Sd_3                 yes        sHoliday_11  below_average
# 52               Sd_3                  no        sHoliday_13       generous
# 53               Sd_6                  no        sHoliday_11        average
# 54               Sd_6                  no        sHoliday_11       generous
# 55               Sd_3                  no        sHoliday_12        average
# 56              Sd_14                  no         sHoliday_9       generous
#
#    longterm-disability-assistance contribution-to-dental-plan  \
# 0                             yes                        half
# 1                             yes                        full
# 2                             yes                        half
# 3                             yes                        half
# 4                             yes                        half
# 5                             yes                        half
# 6                             yes             dentalplan_none
# 7                             yes                        half
# 8                             yes                        half
# 9                             yes                        full
# 10                            yes                        half
# 11                            yes                        full
# 12                             no                        half
# 13                            yes                        full
# 14                            yes                        half
# 15                            yes                        full
# 16                            yes                        half
# 17                            yes                        half
# 18                             no             dentalplan_none
# 19                            yes                        half
# 20                            yes                        full
# 21                            yes                        half
# 22                            yes                        half
# 23                            yes                        half
# 24                            yes                        half
# 25                            yes                        half
# 26                            yes             dentalplan_none
# 27                            yes                        half
# 28                            yes                        full
# 29                            yes                        half
# 30                            yes                        half
# 31                            yes                        half
# 32                            yes                        half
# 33                             no             dentalplan_none
# 34                             no                        half
# 35                            yes             dentalplan_none
# 36                             no             dentalplan_none
# 37                            yes                        half
# 38                            yes                        half
# 39                            yes                        full
# 40                             no             dentalplan_none
# 41                            yes             dentalplan_none
# 42                            yes                        half
# 43                            yes                        half
# 44                             no             dentalplan_none
# 45                             no                        half
# 46                            yes                        full
# 47                            yes                        half
# 48                            yes                        half
# 49                            yes                        full
# 50                            yes                        full
# 51                            yes                        half
# 52                            yes                        half
# 53                            yes                        full
# 54                            yes                        half
# 55                            yes                        half
# 56                            yes                        full
#
#    bereavement-assistance contribution-to-health-plan
# 0                     yes                        full
# 1                     yes                        full
# 2                     yes                        half
# 3                     yes                        full
# 4                     yes                        half
# 5                     yes                        full
# 6                     yes                        half
# 7                     yes                        full
# 8                     yes                        full
# 9                     yes                        full
# 10                    yes                        full
# 11                    yes                        full
# 12                    yes                        half
# 13                    yes                        full
# 14                    yes                        full
# 15                    yes                        full
# 16                    yes                        full
# 17                    yes             healtsplan_none
# 18                     no             healtsplan_none
# 19                    yes                        full
# 20                    yes                        full
# 21                    yes                        full
# 22                    yes                        full
# 23                    yes                        full
# 24                    yes                        full
# 25                    yes                        full
# 26                    yes                        half
# 27                    yes                        full
# 28                    yes                        full
# 29                    yes                        full
# 30                    yes                        full
# 31                    yes                        full
# 32                    yes                        full
# 33                    yes             healtsplan_none
# 34                    yes                        full
# 35                    yes                        full
# 36                     no             healtsplan_none
# 37                    yes             healtsplan_none
# 38                    yes             healtsplan_none
# 39                    yes                        half
# 40                     no             healtsplan_none
# 41                    yes                        full
# 42                    yes                        full
# 43                    yes                        full
# 44                    yes             healtsplan_none
# 45                    yes                        half
# 46                    yes                        full
# 47                    yes                        half
# 48                    yes                        full
# 49                    yes                        full
# 50                    yes                        full
# 51                    yes                        full
# 52                    yes                        full
# 53                    yes                        full
# 54                    yes                        full
# 55                    yes                        half
# 56                    yes                        full

# %% [markdown]
# Lihat Deskripsi Keseluruhan Data

# %%
# Deskripsi keseluruhan data
data.describe(include='all')
# Out:
#          duration WIFirstYear WISecondYear WIThirdYear  \
# count          57          57           57          57
# unique          4          17           15           9
# top     duration2  wageFirst2  wageSecond4  wageThrid5
# freq           27          11           24          47
#
#        cost-of-living-adjustment   working-hours     pension  standby-pay  \
# count                         57              57          57           57
# unique                         3               8           3            7
# top                     colanone  workinghours40  empl_contr  standByPay2
# freq                          42              29          42           51
#
#        shift-differential education-allowance statutory-holidays  \
# count                  57                  57                 57
# unique                 10                   2                  6
# top                  Sd_3                  no        sHoliday_11
# freq                   33                  47                 25
#
#              vacation longterm-disability-assistance  \
# count              57                             57
# unique              3                              2
# top     below_average                            yes
# freq               24                             49
#
#        contribution-to-dental-plan bereavement-assistance  \
# count                           57                     57
# unique                           3                      2
# top                           half                    yes
# freq                            35                     54
#
#        contribution-to-health-plan
# count                           57
# unique                           3
# top                           full
# freq                            40

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig = plt.figure(figsize=(15,5))
colors = sns.color_palette("YlOrRd", 25)
names = data.duration.value_counts().head(25).index
values = data.duration.value_counts().head(25)
sns.barplot(x = names, y = values, palette = colors)
plt.xticks(rotation=60)
# Out:
# (array([0, 1, 2, 3]), <a list of 4 Text xticklabel objects>)

# %%
fig = plt.figure(figsize=(15,5))
colors = sns.color_palette("YlOrRd", 25)
names = data.pension.value_counts().head(25).index
values = data.pension.value_counts().head(25)
sns.barplot(x = names, y = values, palette = colors)
plt.xticks(rotation=60)
# Out:
# (array([0, 1, 2]), <a list of 3 Text xticklabel objects>)

# %%
records = []
for i in range(0, 57):
    records.append([str(data.values[i,j]) for j in range(0, 16)])
rules = apriori(records, min_support = 0.00030, min_confidence = 0.05, min_lift = 3, max_length = 2, target = "rules")
association_results = list(rules)
print(association_results[0])
# Out:
# RelationRecord(items=frozenset({'2', 'Sd_5'}), support=0.017543859649122806, ordered_statistics=[OrderedStatistic(items_base=frozenset({'2'}), items_add=frozenset({'Sd_5'}), confidence=1.0, lift=9.5), OrderedStatistic(items_base=frozenset({'Sd_5'}), items_add=frozenset({'2'}), confidence=0.16666666666666666, lift=9.5)])

# %%
for item in association_results:
    
    pair = item[0]
    items = [x for x in pair]
    
    print("Rule : ", items[0], " -> " + items[1])
    print("Support : ", str(item[1]))
    print("Confidence : ",str(item[2][0][2]))
    print("Lift : ", str(item[2][0][3]))
    
    print("=============================")
# Out:
# Rule :  2  -> Sd_5
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  9.5
# =============================
# Rule :  2  -> generous
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  3.5625
# =============================
# Rule :  2  -> wageFirst2
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  5.1818181818181825
# =============================
# Rule :  2  -> workinghours38
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  4.75
# =============================
# Rule :  colatc  -> Sd_0
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  8.142857142857144
# =============================
# Rule :  Sd_0  -> dentalplan_none
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  6.333333333333334
# =============================
# Rule :  duration1  -> Sd_0
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  5.7
# =============================
# Rule :  generous  -> Sd_0
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  3.5625
# =============================
# Rule :  Sd_0  -> healtsplan_none
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  7.125
# =============================
# Rule :  ret_allw  -> Sd_0
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  14.25
# =============================
# Rule :  standByPay4  -> Sd_0
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  57.0
# =============================
# Rule :  Sd_0  -> wageFirst2
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  5.1818181818181825
# =============================
# Rule :  Sd_1  -> colatc
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  8.142857142857144
# =============================
# Rule :  Sd_1  -> duration3
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  3.0
# =============================
# Rule :  Sd_1  -> pensioun_none
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  5.1818181818181825
# =============================
# Rule :  Sd_1  -> sHoliday_10
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  4.75
# =============================
# Rule :  Sd_1  -> wageFirst2
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  5.1818181818181825
# =============================
# Rule :  Sd_1  -> wageSecond2.5
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  9.5
# =============================
# Rule :  Sd_1  -> wageThrid2.1
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  57.0
# =============================
# Rule :  duration1  -> Sd_10
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  5.7
# =============================
# Rule :  generous  -> Sd_10
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  3.5625
# =============================
# Rule :  wageFirst3  -> Sd_10
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  14.25
# =============================
# Rule :  workinghours36  -> Sd_10
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  28.5
# =============================
# Rule :  duration3  -> Sd_14
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  3.0
# =============================
# Rule :  generous  -> Sd_14
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  3.5625
# =============================
# Rule :  Sd_14  -> sHoliday_9
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  14.25
# =============================
# Rule :  wageFirst6  -> Sd_14
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  28.5
# =============================
# Rule :  wageSecond6  -> Sd_14
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  57.0
# =============================
# Rule :  wageThrid4  -> Sd_14
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  57.0
# =============================
# Rule :  workinghours35  -> Sd_14
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  8.142857142857144
# =============================
# Rule :  wageFirst2.8  -> Sd_2
# Support :  0.017543859649122806
# Confidence :  0.25
# Lift :  7.125
# =============================
# Rule :  Sd_25  -> standByPay12
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  57.0
# =============================
# Rule :  wageFirst3  -> Sd_25
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  14.25
# =============================
# Rule :  Sd_25  -> wageSecond7
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  57.0
# =============================
# Rule :  Sd_25  -> workinghours38
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  4.75
# =============================
# Rule :  sHoliday_13  -> Sd_4
# Support :  0.017543859649122806
# Confidence :  0.16666666666666666
# Lift :  3.1666666666666665
# =============================
# Rule :  sHoliday_15  -> Sd_4
# Support :  0.017543859649122806
# Confidence :  0.16666666666666666
# Lift :  4.75
# =============================
# Rule :  wageFirst4.3  -> Sd_4
# Support :  0.017543859649122806
# Confidence :  0.16666666666666666
# Lift :  9.5
# =============================
# Rule :  wageFirst5.7  -> Sd_4
# Support :  0.017543859649122806
# Confidence :  0.16666666666666666
# Lift :  4.75
# =============================
# Rule :  Sd_4  -> wageFirst6.4
# Support :  0.017543859649122806
# Confidence :  0.16666666666666666
# Lift :  9.5
# =============================
# Rule :  Sd_4  -> wageSecond4.4
# Support :  0.017543859649122806
# Confidence :  0.16666666666666666
# Lift :  4.75
# =============================
# Rule :  wageSecond6.4  -> Sd_4
# Support :  0.017543859649122806
# Confidence :  0.16666666666666666
# Lift :  9.5
# =============================
# Rule :  wageThrid5.1  -> Sd_4
# Support :  0.017543859649122806
# Confidence :  0.16666666666666666
# Lift :  9.5
# =============================
# Rule :  sHoliday_15  -> Sd_5
# Support :  0.017543859649122806
# Confidence :  0.16666666666666666
# Lift :  4.75
# =============================
# Rule :  standByPay13  -> Sd_5
# Support :  0.017543859649122806
# Confidence :  0.16666666666666666
# Lift :  9.5
# =============================
# Rule :  standByPay14  -> Sd_5
# Support :  0.017543859649122806
# Confidence :  0.16666666666666666
# Lift :  9.5
# =============================
# Rule :  wageFirst5  -> Sd_5
# Support :  0.03508771929824561
# Confidence :  0.3333333333333333
# Lift :  3.8
# =============================
# Rule :  wageSecond2  -> Sd_5
# Support :  0.017543859649122806
# Confidence :  0.16666666666666666
# Lift :  3.1666666666666665
# =============================
# Rule :  wageThrid2.5  -> Sd_5
# Support :  0.017543859649122806
# Confidence :  0.16666666666666666
# Lift :  9.5
# =============================
# Rule :  standByPay10  -> Sd_6
# Support :  0.017543859649122806
# Confidence :  0.3333333333333333
# Lift :  19.0
# =============================
# Rule :  wageFirst4  -> Sd_6
# Support :  0.017543859649122806
# Confidence :  0.3333333333333333
# Lift :  3.1666666666666665
# =============================
# Rule :  wageFirst5  -> Sd_6
# Support :  0.017543859649122806
# Confidence :  0.3333333333333333
# Lift :  3.8
# =============================
# Rule :  wageSecond2.5  -> Sd_6
# Support :  0.017543859649122806
# Confidence :  0.3333333333333333
# Lift :  3.1666666666666665
# =============================
# Rule :  wageSecond3.5  -> Sd_6
# Support :  0.017543859649122806
# Confidence :  0.3333333333333333
# Lift :  19.0
# =============================
# Rule :  wageSecond4.4  -> Sd_6
# Support :  0.017543859649122806
# Confidence :  0.3333333333333333
# Lift :  9.5
# =============================
# Rule :  wageSecond3.5  -> average
# Support :  0.017543859649122806
# Confidence :  0.058823529411764705
# Lift :  3.3529411764705883
# =============================
# Rule :  workinghours39  -> average
# Support :  0.017543859649122806
# Confidence :  0.058823529411764705
# Lift :  3.3529411764705883
# =============================
# Rule :  ret_allw  -> colatc
# Support :  0.03508771929824561
# Confidence :  0.2857142857142857
# Lift :  4.071428571428571
# =============================
# Rule :  standByPay4  -> colatc
# Support :  0.017543859649122806
# Confidence :  0.14285714285714285
# Lift :  8.142857142857142
# =============================
# Rule :  colatc  -> wageFirst2.1
# Support :  0.017543859649122806
# Confidence :  0.14285714285714285
# Lift :  8.142857142857142
# =============================
# Rule :  colatc  -> wageFirst3.7
# Support :  0.017543859649122806
# Confidence :  0.14285714285714285
# Lift :  8.142857142857142
# =============================
# Rule :  colatc  -> wageThrid2.1
# Support :  0.017543859649122806
# Confidence :  0.14285714285714285
# Lift :  8.142857142857142
# =============================
# Rule :  colatc  -> wageThrid2.5
# Support :  0.017543859649122806
# Confidence :  0.14285714285714285
# Lift :  8.142857142857142
# =============================
# Rule :  colatc  -> workinghours39
# Support :  0.017543859649122806
# Confidence :  0.14285714285714285
# Lift :  8.142857142857142
# =============================
# Rule :  colatcf  -> sHoliday_13
# Support :  0.03508771929824561
# Confidence :  0.25
# Lift :  4.75
# =============================
# Rule :  colatcf  -> sHoliday_15
# Support :  0.017543859649122806
# Confidence :  0.125
# Lift :  3.5625
# =============================
# Rule :  colatcf  -> standByPay13
# Support :  0.017543859649122806
# Confidence :  0.125
# Lift :  7.125
# =============================
# Rule :  colatcf  -> wageFirst3.5
# Support :  0.05263157894736842
# Confidence :  0.375
# Lift :  4.275
# =============================
# Rule :  colatcf  -> wageFirst4.6
# Support :  0.017543859649122806
# Confidence :  0.125
# Lift :  7.125
# =============================
# Rule :  colatcf  -> wageSecond4.6
# Support :  0.017543859649122806
# Confidence :  0.125
# Lift :  7.125
# =============================
# Rule :  colatcf  -> wageThrid4.5
# Support :  0.017543859649122806
# Confidence :  0.125
# Lift :  7.125
# =============================
# Rule :  colatcf  -> wageThrid4.6
# Support :  0.017543859649122806
# Confidence :  0.125
# Lift :  3.5625
# =============================
# Rule :  colatcf  -> wageThrid5.1
# Support :  0.017543859649122806
# Confidence :  0.125
# Lift :  7.125
# =============================
# Rule :  workinghours27  -> colatcf
# Support :  0.017543859649122806
# Confidence :  0.125
# Lift :  7.125
# =============================
# Rule :  dentalplan_none  -> healtsplan_none
# Support :  0.08771929824561403
# Confidence :  0.5555555555555556
# Lift :  3.958333333333334
# =============================
# Rule :  standByPay4  -> dentalplan_none
# Support :  0.017543859649122806
# Confidence :  0.1111111111111111
# Lift :  6.333333333333333
# =============================
# Rule :  dentalplan_none  -> wageFirst4
# Support :  0.07017543859649122
# Confidence :  0.4444444444444444
# Lift :  4.222222222222222
# =============================
# Rule :  wageSecond5  -> dentalplan_none
# Support :  0.03508771929824561
# Confidence :  0.2222222222222222
# Lift :  3.1666666666666665
# =============================
# Rule :  duration1  -> healtsplan_none
# Support :  0.08771929824561403
# Confidence :  0.5
# Lift :  3.5625
# =============================
# Rule :  duration1  -> sHoliday_9
# Support :  0.05263157894736842
# Confidence :  0.3
# Lift :  4.275
# =============================
# Rule :  standByPay4  -> duration1
# Support :  0.017543859649122806
# Confidence :  0.1
# Lift :  5.700000000000001
# =============================
# Rule :  standByPay8  -> duration1
# Support :  0.017543859649122806
# Confidence :  0.1
# Lift :  5.700000000000001
# =============================
# Rule :  wageFirst2.1  -> duration1
# Support :  0.017543859649122806
# Confidence :  0.1
# Lift :  5.700000000000001
# =============================
# Rule :  wageFirst2.8  -> duration1
# Support :  0.03508771929824561
# Confidence :  0.2
# Lift :  5.700000000000001
# =============================
# Rule :  duration3  -> sHoliday_13
# Support :  0.05263157894736842
# Confidence :  0.15789473684210525
# Lift :  3.0
# =============================
# Rule :  duration3  -> standByPay10
# Support :  0.017543859649122806
# Confidence :  0.05263157894736842
# Lift :  3.0
# =============================
# Rule :  duration3  -> wageFirst3.7
# Support :  0.017543859649122806
# Confidence :  0.05263157894736842
# Lift :  3.0
# =============================
# Rule :  duration3  -> wageFirst6.9
# Support :  0.017543859649122806
# Confidence :  0.05263157894736842
# Lift :  3.0
# =============================
# Rule :  duration3  -> wageSecond3.5
# Support :  0.017543859649122806
# Confidence :  0.05263157894736842
# Lift :  3.0
# =============================
# Rule :  duration3  -> wageSecond4.8
# Support :  0.017543859649122806
# Confidence :  0.05263157894736842
# Lift :  3.0
# =============================
# Rule :  duration3  -> wageSecond6
# Support :  0.017543859649122806
# Confidence :  0.05263157894736842
# Lift :  3.0
# =============================
# Rule :  duration3  -> wageThrid2
# Support :  0.03508771929824561
# Confidence :  0.10526315789473684
# Lift :  3.0
# =============================
# Rule :  duration3  -> wageThrid2.1
# Support :  0.017543859649122806
# Confidence :  0.05263157894736842
# Lift :  3.0
# =============================
# Rule :  duration3  -> wageThrid2.3
# Support :  0.017543859649122806
# Confidence :  0.05263157894736842
# Lift :  3.0
# =============================
# Rule :  duration3  -> wageThrid2.5
# Support :  0.017543859649122806
# Confidence :  0.05263157894736842
# Lift :  3.0
# =============================
# Rule :  duration3  -> wageThrid4
# Support :  0.017543859649122806
# Confidence :  0.05263157894736842
# Lift :  3.0
# =============================
# Rule :  duration3  -> wageThrid4.5
# Support :  0.017543859649122806
# Confidence :  0.05263157894736842
# Lift :  3.0
# =============================
# Rule :  duration3  -> wageThrid4.6
# Support :  0.03508771929824561
# Confidence :  0.10526315789473684
# Lift :  3.0
# =============================
# Rule :  duration3  -> wageThrid5.1
# Support :  0.017543859649122806
# Confidence :  0.05263157894736842
# Lift :  3.0
# =============================
# Rule :  duration3  -> workinghours27
# Support :  0.017543859649122806
# Confidence :  0.05263157894736842
# Lift :  3.0
# =============================
# Rule :  generous  -> sHoliday_13
# Support :  0.05263157894736842
# Confidence :  0.1875
# Lift :  3.5625
# =============================
# Rule :  generous  -> standByPay10
# Support :  0.017543859649122806
# Confidence :  0.0625
# Lift :  3.5625
# =============================
# Rule :  generous  -> standByPay13
# Support :  0.017543859649122806
# Confidence :  0.0625
# Lift :  3.5625
# =============================
# Rule :  generous  -> standByPay4
# Support :  0.017543859649122806
# Confidence :  0.0625
# Lift :  3.5625
# =============================
# Rule :  generous  -> standByPay8
# Support :  0.017543859649122806
# Confidence :  0.0625
# Lift :  3.5625
# =============================
# Rule :  generous  -> wageFirst4.3
# Support :  0.017543859649122806
# Confidence :  0.0625
# Lift :  3.5625
# =============================
# Rule :  generous  -> wageFirst6
# Support :  0.03508771929824561
# Confidence :  0.125
# Lift :  3.5625
# =============================
# Rule :  generous  -> wageSecond4.4
# Support :  0.03508771929824561
# Confidence :  0.125
# Lift :  3.5625
# =============================
# Rule :  generous  -> wageSecond6
# Support :  0.017543859649122806
# Confidence :  0.0625
# Lift :  3.5625
# =============================
# Rule :  generous  -> wageThrid4
# Support :  0.017543859649122806
# Confidence :  0.0625
# Lift :  3.5625
# =============================
# Rule :  generous  -> wageThrid4.5
# Support :  0.017543859649122806
# Confidence :  0.0625
# Lift :  3.5625
# =============================
# Rule :  generous  -> wageThrid5.1
# Support :  0.017543859649122806
# Confidence :  0.0625
# Lift :  3.5625
# =============================
# Rule :  generous  -> workinghours33
# Support :  0.017543859649122806
# Confidence :  0.0625
# Lift :  3.5625
# =============================
# Rule :  generous  -> workinghours36
# Support :  0.03508771929824561
# Confidence :  0.125
# Lift :  3.5625
# =============================
# Rule :  ret_allw  -> healtsplan_none
# Support :  0.03508771929824561
# Confidence :  0.25
# Lift :  3.5625
# =============================
# Rule :  healtsplan_none  -> sHoliday_9
# Support :  0.03508771929824561
# Confidence :  0.25
# Lift :  3.5625
# =============================
# Rule :  standByPay4  -> healtsplan_none
# Support :  0.017543859649122806
# Confidence :  0.125
# Lift :  7.125
# =============================
# Rule :  wageFirst2.1  -> healtsplan_none
# Support :  0.017543859649122806
# Confidence :  0.125
# Lift :  7.125
# =============================
# Rule :  wageFirst2.8  -> healtsplan_none
# Support :  0.017543859649122806
# Confidence :  0.125
# Lift :  3.5625
# =============================
# Rule :  healtsplan_none  -> wageFirst4
# Support :  0.05263157894736842
# Confidence :  0.375
# Lift :  3.5625
# =============================
# Rule :  wageThrid2  -> healtsplan_none
# Support :  0.017543859649122806
# Confidence :  0.125
# Lift :  3.5625
# =============================
# Rule :  wageSecond2  -> pensioun_none
# Support :  0.05263157894736842
# Confidence :  0.2727272727272727
# Lift :  5.181818181818182
# =============================
# Rule :  wageThrid2.1  -> pensioun_none
# Support :  0.017543859649122806
# Confidence :  0.09090909090909091
# Lift :  5.1818181818181825
# =============================
# Rule :  wageThrid2.5  -> pensioun_none
# Support :  0.017543859649122806
# Confidence :  0.09090909090909091
# Lift :  5.1818181818181825
# =============================
# Rule :  ret_allw  -> sHoliday_9
# Support :  0.017543859649122806
# Confidence :  0.25
# Lift :  3.5625
# =============================
# Rule :  standByPay4  -> ret_allw
# Support :  0.017543859649122806
# Confidence :  0.25
# Lift :  14.25
# =============================
# Rule :  ret_allw  -> wageFirst2.1
# Support :  0.017543859649122806
# Confidence :  0.25
# Lift :  14.25
# =============================
# Rule :  ret_allw  -> wageFirst5.7
# Support :  0.017543859649122806
# Confidence :  0.25
# Lift :  7.125
# =============================
# Rule :  wageSecond5.8  -> ret_allw
# Support :  0.017543859649122806
# Confidence :  0.25
# Lift :  14.25
# =============================
# Rule :  wageSecond2  -> sHoliday_10
# Support :  0.03508771929824561
# Confidence :  0.16666666666666666
# Lift :  3.1666666666666665
# =============================
# Rule :  wageSecond2.5  -> sHoliday_10
# Support :  0.07017543859649122
# Confidence :  0.3333333333333333
# Lift :  3.1666666666666665
# =============================
# Rule :  sHoliday_10  -> wageThrid2
# Support :  0.03508771929824561
# Confidence :  0.16666666666666666
# Lift :  4.75
# =============================
# Rule :  wageThrid2.1  -> sHoliday_10
# Support :  0.017543859649122806
# Confidence :  0.08333333333333333
# Lift :  4.75
# =============================
# Rule :  sHoliday_10  -> wageThrid2.5
# Support :  0.017543859649122806
# Confidence :  0.08333333333333333
# Lift :  4.75
# =============================
# Rule :  wageFirst4.3  -> sHoliday_12
# Support :  0.017543859649122806
# Confidence :  0.09090909090909091
# Lift :  5.1818181818181825
# =============================
# Rule :  wageFirst6.9  -> sHoliday_12
# Support :  0.017543859649122806
# Confidence :  0.09090909090909091
# Lift :  5.1818181818181825
# =============================
# Rule :  wageSecond4.8  -> sHoliday_12
# Support :  0.017543859649122806
# Confidence :  0.09090909090909091
# Lift :  5.1818181818181825
# =============================
# Rule :  wageThrid2.3  -> sHoliday_12
# Support :  0.017543859649122806
# Confidence :  0.09090909090909091
# Lift :  5.1818181818181825
# =============================
# Rule :  workinghours33  -> sHoliday_12
# Support :  0.017543859649122806
# Confidence :  0.09090909090909091
# Lift :  5.1818181818181825
# =============================
# Rule :  workinghours39  -> sHoliday_12
# Support :  0.017543859649122806
# Confidence :  0.09090909090909091
# Lift :  5.1818181818181825
# =============================
# Rule :  wageFirst3.5  -> sHoliday_13
# Support :  0.05263157894736842
# Confidence :  1.0
# Lift :  11.4
# =============================
# Rule :  sHoliday_13  -> wageThrid4.5
# Support :  0.017543859649122806
# Confidence :  0.3333333333333333
# Lift :  19.0
# =============================
# Rule :  sHoliday_13  -> wageThrid4.6
# Support :  0.017543859649122806
# Confidence :  0.3333333333333333
# Lift :  9.5
# =============================
# Rule :  sHoliday_13  -> wageThrid5.1
# Support :  0.017543859649122806
# Confidence :  0.3333333333333333
# Lift :  19.0
# =============================
# Rule :  sHoliday_13  -> workinghours36
# Support :  0.017543859649122806
# Confidence :  0.3333333333333333
# Lift :  9.5
# =============================
# Rule :  sHoliday_13  -> workinghours37
# Support :  0.017543859649122806
# Confidence :  0.3333333333333333
# Lift :  4.75
# =============================
# Rule :  standByPay13  -> sHoliday_15
# Support :  0.017543859649122806
# Confidence :  0.5
# Lift :  28.5
# =============================
# Rule :  sHoliday_15  -> wageFirst4
# Support :  0.017543859649122806
# Confidence :  0.5
# Lift :  4.75
# =============================
# Rule :  sHoliday_15  -> wageFirst6.4
# Support :  0.017543859649122806
# Confidence :  0.5
# Lift :  28.5
# =============================
# Rule :  wageSecond5  -> sHoliday_15
# Support :  0.017543859649122806
# Confidence :  0.5
# Lift :  7.125
# =============================
# Rule :  wageSecond6.4  -> sHoliday_15
# Support :  0.017543859649122806
# Confidence :  0.5
# Lift :  28.5
# =============================
# Rule :  workinghours35  -> sHoliday_15
# Support :  0.017543859649122806
# Confidence :  0.5
# Lift :  4.071428571428572
# =============================
# Rule :  standByPay8  -> sHoliday_9
# Support :  0.017543859649122806
# Confidence :  0.25
# Lift :  14.25
# =============================
# Rule :  wageFirst2.1  -> sHoliday_9
# Support :  0.017543859649122806
# Confidence :  0.25
# Lift :  14.25
# =============================
# Rule :  wageFirst2.8  -> sHoliday_9
# Support :  0.017543859649122806
# Confidence :  0.25
# Lift :  7.125
# =============================
# Rule :  wageFirst6  -> sHoliday_9
# Support :  0.03508771929824561
# Confidence :  0.5
# Lift :  14.25
# =============================
# Rule :  wageSecond6  -> sHoliday_9
# Support :  0.017543859649122806
# Confidence :  0.25
# Lift :  14.25
# =============================
# Rule :  wageThrid4  -> sHoliday_9
# Support :  0.017543859649122806
# Confidence :  0.25
# Lift :  14.25
# =============================
# Rule :  wageFirst5  -> standByPay10
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  11.4
# =============================
# Rule :  standByPay10  -> wageSecond4.4
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  28.5
# =============================
# Rule :  standByPay10  -> workinghours38
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  4.75
# =============================
# Rule :  wageFirst3  -> standByPay12
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  14.25
# =============================
# Rule :  wageSecond7  -> standByPay12
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  57.0
# =============================
# Rule :  workinghours38  -> standByPay12
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  4.75
# =============================
# Rule :  standByPay13  -> wageFirst4
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  9.5
# =============================
# Rule :  wageSecond5  -> standByPay13
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  14.25
# =============================
# Rule :  workinghours35  -> standByPay13
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  8.142857142857144
# =============================
# Rule :  wageFirst5  -> standByPay14
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  11.4
# =============================
# Rule :  wageSecond4.5  -> standByPay14
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  11.4
# =============================
# Rule :  workinghours38  -> standByPay14
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  4.75
# =============================
# Rule :  standByPay4  -> wageFirst2
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  5.1818181818181825
# =============================
# Rule :  standByPay8  -> wageFirst6
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  28.5
# =============================
# Rule :  standByPay8  -> workinghours38
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  4.75
# =============================
# Rule :  wageSecond2  -> wageFirst2
# Support :  0.03508771929824561
# Confidence :  0.18181818181818182
# Lift :  3.454545454545455
# =============================
# Rule :  wageSecond2.5  -> wageFirst2
# Support :  0.07017543859649122
# Confidence :  0.36363636363636365
# Lift :  3.454545454545455
# =============================
# Rule :  wageThrid2  -> wageFirst2
# Support :  0.03508771929824561
# Confidence :  0.18181818181818182
# Lift :  5.1818181818181825
# =============================
# Rule :  wageThrid2.1  -> wageFirst2
# Support :  0.017543859649122806
# Confidence :  0.09090909090909091
# Lift :  5.1818181818181825
# =============================
# Rule :  wageFirst2.5  -> wageSecond2.5
# Support :  0.03508771929824561
# Confidence :  0.5
# Lift :  4.75
# =============================
# Rule :  wageFirst2.5  -> wageSecond3
# Support :  0.03508771929824561
# Confidence :  0.5
# Lift :  5.7
# =============================
# Rule :  wageFirst2.5  -> workinghours39
# Support :  0.017543859649122806
# Confidence :  0.25
# Lift :  14.25
# =============================
# Rule :  wageFirst2.8  -> workinghours35
# Support :  0.017543859649122806
# Confidence :  0.5
# Lift :  4.071428571428572
# =============================
# Rule :  wageFirst3  -> wageSecond2
# Support :  0.017543859649122806
# Confidence :  0.25
# Lift :  4.75
# =============================
# Rule :  wageFirst3  -> wageSecond7
# Support :  0.017543859649122806
# Confidence :  0.25
# Lift :  14.25
# =============================
# Rule :  wageFirst3  -> wageThrid2.5
# Support :  0.017543859649122806
# Confidence :  0.25
# Lift :  14.25
# =============================
# Rule :  wageFirst3  -> workinghours33
# Support :  0.017543859649122806
# Confidence :  0.25
# Lift :  14.25
# =============================
# Rule :  wageFirst3  -> workinghours36
# Support :  0.017543859649122806
# Confidence :  0.25
# Lift :  7.125
# =============================
# Rule :  wageFirst3.5  -> wageThrid4.5
# Support :  0.017543859649122806
# Confidence :  0.2
# Lift :  11.400000000000002
# =============================
# Rule :  wageFirst3.5  -> wageThrid4.6
# Support :  0.03508771929824561
# Confidence :  0.4
# Lift :  11.400000000000002
# =============================
# Rule :  wageFirst3.5  -> wageThrid5.1
# Support :  0.017543859649122806
# Confidence :  0.2
# Lift :  11.400000000000002
# =============================
# Rule :  workinghours27  -> wageFirst3.5
# Support :  0.017543859649122806
# Confidence :  0.2
# Lift :  11.400000000000002
# =============================
# Rule :  wageFirst3.5  -> workinghours36
# Support :  0.017543859649122806
# Confidence :  0.2
# Lift :  5.700000000000001
# =============================
# Rule :  wageSecond3.5  -> wageFirst4
# Support :  0.017543859649122806
# Confidence :  0.16666666666666666
# Lift :  9.5
# =============================
# Rule :  wageSecond5  -> wageFirst4
# Support :  0.05263157894736842
# Confidence :  0.5
# Lift :  7.125
# =============================
# Rule :  wageFirst4.3  -> wageSecond4.4
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  28.5
# =============================
# Rule :  wageFirst4.3  -> workinghours38
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  4.75
# =============================
# Rule :  wageFirst4.5  -> wageSecond4.5
# Support :  0.05263157894736842
# Confidence :  0.3333333333333333
# Lift :  3.8
# =============================
# Rule :  wageSecond5.8  -> wageFirst4.5
# Support :  0.017543859649122806
# Confidence :  0.1111111111111111
# Lift :  6.333333333333333
# =============================
# Rule :  wageFirst4.6  -> wageSecond4.6
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  57.0
# =============================
# Rule :  wageFirst4.6  -> workinghours38
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  4.75
# =============================
# Rule :  wageFirst5  -> wageSecond4.4
# Support :  0.017543859649122806
# Confidence :  0.2
# Lift :  5.700000000000001
# =============================
# Rule :  wageFirst5.7  -> wageSecond4.5
# Support :  0.017543859649122806
# Confidence :  0.5
# Lift :  5.7
# =============================
# Rule :  wageFirst6  -> wageSecond6
# Support :  0.017543859649122806
# Confidence :  0.5
# Lift :  28.5
# =============================
# Rule :  wageThrid4  -> wageFirst6
# Support :  0.017543859649122806
# Confidence :  0.5
# Lift :  28.5
# =============================
# Rule :  workinghours35  -> wageFirst6
# Support :  0.017543859649122806
# Confidence :  0.5
# Lift :  4.071428571428572
# =============================
# Rule :  wageSecond6.4  -> wageFirst6.4
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  57.0
# =============================
# Rule :  workinghours38  -> wageFirst6.4
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  4.75
# =============================
# Rule :  wageFirst6.9  -> wageSecond4.8
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  57.0
# =============================
# Rule :  wageThrid2.3  -> wageFirst6.9
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  57.0
# =============================
# Rule :  wageSecond5.3  -> wageFirst7
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  57.0
# =============================
# Rule :  wageSecond2  -> wageThrid2
# Support :  0.017543859649122806
# Confidence :  0.3333333333333333
# Lift :  9.5
# =============================
# Rule :  wageSecond2  -> wageThrid2.5
# Support :  0.017543859649122806
# Confidence :  0.3333333333333333
# Lift :  19.0
# =============================
# Rule :  wageSecond2.5  -> wageThrid2
# Support :  0.017543859649122806
# Confidence :  0.16666666666666666
# Lift :  4.75
# =============================
# Rule :  wageSecond2.5  -> wageThrid2.1
# Support :  0.017543859649122806
# Confidence :  0.16666666666666666
# Lift :  9.5
# =============================
# Rule :  wageSecond2.5  -> workinghours39
# Support :  0.017543859649122806
# Confidence :  0.16666666666666666
# Lift :  9.5
# =============================
# Rule :  wageSecond3  -> workinghours33
# Support :  0.017543859649122806
# Confidence :  0.2
# Lift :  11.400000000000002
# =============================
# Rule :  workinghours38  -> wageSecond4.4
# Support :  0.03508771929824561
# Confidence :  1.0
# Lift :  4.75
# =============================
# Rule :  workinghours38  -> wageSecond4.6
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  4.75
# =============================
# Rule :  wageThrid2.3  -> wageSecond4.8
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  57.0
# =============================
# Rule :  wageSecond5.8  -> workinghours35
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  8.142857142857144
# =============================
# Rule :  wageThrid4  -> wageSecond6
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  57.0
# =============================
# Rule :  workinghours35  -> wageSecond6
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  8.142857142857144
# =============================
# Rule :  wageSecond6.4  -> workinghours38
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  4.75
# =============================
# Rule :  wageSecond7  -> workinghours38
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  4.75
# =============================
# Rule :  workinghours37  -> wageThrid2
# Support :  0.017543859649122806
# Confidence :  0.5
# Lift :  7.125
# =============================
# Rule :  wageThrid4  -> workinghours35
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  8.142857142857144
# =============================
# Rule :  workinghours35  -> wageThrid4.5
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  8.142857142857144
# =============================
# Rule :  workinghours27  -> wageThrid4.6
# Support :  0.017543859649122806
# Confidence :  0.5
# Lift :  28.5
# =============================
# Rule :  workinghours36  -> wageThrid4.6
# Support :  0.017543859649122806
# Confidence :  0.5
# Lift :  14.25
# =============================
# Rule :  workinghours37  -> wageThrid5.1
# Support :  0.017543859649122806
# Confidence :  1.0
# Lift :  14.25
# =============================
